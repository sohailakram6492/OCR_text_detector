# %%
# !pip install pillow
# !pip install pytesseract
# Out:
# Requirement already satisfied: pillow in c:\users\sohai\appdata\local\programs\python\python37\lib\site-packages (8.4.0)
# Requirement already satisfied: pytesseract in c:\users\sohai\appdata\local\programs\python\python37\lib\site-packages (0.3.8)
# Requirement already satisfied: Pillow in c:\users\sohai\appdata\local\programs\python\python37\lib\site-packages (from pytesseract) (8.4.0)

# %%
from PIL import Image
import pytesseract
import os

# %%
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files (x86)\Tesseract-OCR\tesseract.exe" 
images=os.listdir(r'C:\Users\sohai\Downloads\NIC Images')
for i in images:
    print(f"========== {i}  ==========")
    text = pytesseract.image_to_string(f'NIC Images/{i}')
    print(text)
# Out:
# ========== 1.jpg  ==========
# 3 rA_>qsr,m»..........c... -
#
# 's'.‘.‘».mmn
#
#
#
# ; ;L'.!!L
# ....... \I~u..m;-v
#
# Iumn ‘ mun ._ﬁ.—
#
#
# ========== 946655ec9a6b979caf72a92066a95872.png  ==========
# _P  Malkulsl Idenmy cam
#
# mum newuxc u; v».kIsuu4
# Mame
#
# Dam af Exwy
#
# I 1B‘10.20Z7 .-..._
#
# Hunter’;
#
#
#
#
# ========== 9e6c9b3c155e80d609fcf50bf3c0df9f.jpg  ==========
# PA.K.|§IA..N
#
# uauuuc aepuauc or must»:
# Name
#
#
#
#
# ========== b40d44d513e237b4205aba8839d3d275.png  ==========
#
#
#
# ========== b77d2a10221415.560e15b0458b6.jpg  ==========
#
#
#
# ========== download.jpg  ==========
#
#
#
# ========== EgR0BxXVAAESPSG.jpg  ==========
#
#
# ;...
# »_r Ihlavllludﬂnuliarooq
#
# _ Julll
# uuuln— _ *
# Mlmlndhrlhnﬂlm
#
# ./J}
# man‘ an. an "
# u M-nun
#
# ;|Tz;'_ '1'"
#
# ) mm xx 1996
#
# u‘.:«$""|ra.‘:.:«'F.?‘ W
#
# nxmou yvwmu ﬁn
# _;
#
#  pnxusmn »--u an en E
#
#
#
#
# ========== EgR6CvyVoAA5HEM.jpg  ==========
#
#
#  National Identity Card
#
# IILADC ZCLK N PHIIIIYAII
#
# Nﬁépera Bibi
#  _. “-!},s§.'./.5’ . _.
# Husband Name
# Muhammad Umar
#
# /1
#
# Gender ltounﬁy of Stay
# F 3 Pakistan
#
# ..#a......._...__
#
# lie-nmy Numhcr To}; 31 am?
# 01202-3199949-4 , 21.12.1997
#
# , _ - _ _.--....
# Dale 0! Issur
#
# 1oax'-Aér £x}:.7y
# 10.12.2018 i 10.12.2028
#
# 'n
#
# under 5 Slgrhaluw
#
#
#
#
# ========== hqdefault.jpg  ==========
# N
# am
# am
# /K
# IA
# ..D.
#
#
#
#
# ========== KP_98535d0d-cimage_story.jpg  ==========
# u
# A.
# M
# .
